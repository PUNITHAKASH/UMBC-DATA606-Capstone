# %%
import pandas as pd

# 1. Loading all datasets (removing the 'Unnamed: 0' index columns during load)
irrigation_data = pd.read_csv("irrigation_prediction.csv", index_col=0)
crop_rec_data = pd.read_csv("Crop_recommendation.csv")
iot_sensor_data = pd.read_csv("irrigation_machine.csv", index_col=0)

# 2. Verify successful loading
print("--- Datasets Loaded Successfully ---")

# 3. Quick Peek at the data structures
print("\nIrrigation Data Shape:", irrigation_data.shape)
print("Crop Recommendation Shape:", crop_rec_data.shape)
print("IoT Sensor Data Shape:", iot_sensor_data.shape)

# Display the first few rows of the primary dataset
irrigation_data.head()
# Out:
# --- Datasets Loaded Successfully ---
#
# Irrigation Data Shape: (10000, 19)
# Crop Recommendation Shape: (2200, 8)
# IoT Sensor Data Shape: (2000, 23)
#            Soil_pH  Soil_Moisture  Organic_Carbon  Electrical_Conductivity  \
# Soil_Type
# Clay          6.14          36.48            0.42                     2.17
# Silt          6.41          50.56            0.38                     0.23
# Sandy         7.71          40.07            1.09                     2.18
# Clay          5.96          12.75            1.56                     0.40
# Clay          7.76          18.58            0.95                     2.52
#
#            Temperature_C  Humidity  Rainfall_mm  Sunlight_Hours  \
# Soil_Type
# Clay               21.90     31.19      1167.70            4.01
# Silt               36.50     26.01       831.28           10.72
# Sandy              41.83     76.41      1844.45            7.75
# Clay               37.22     43.32       306.26            8.90
# ...
